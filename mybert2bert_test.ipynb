# %%
cd drive/MyDrive/Colab/my_bert2bert
# Out:
# /content/drive/MyDrive/Colab/my_bert2bert

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 916 kB 4.2 MB/s
# ...
#      |████████████████████████████████| 748.8 MB 19 kB/s
# ...
#      |████████████████████████████████| 1.4 MB 40.3 MB/s
# ...
#      |████████████████████████████████| 64 kB 2.7 MB/s
# ...
#      |████████████████████████████████| 125 kB 45.0 MB/s
# ...
#      |████████████████████████████████| 829 kB 47.8 MB/s
# ...
#      |████████████████████████████████| 282 kB 39.1 MB/s
# ...
#      |████████████████████████████████| 636 kB 39.9 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 28.9 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 38.8 MB/s
# ...
#      |████████████████████████████████| 895 kB 37.9 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 41.5 MB/s
# ...
#      |████████████████████████████████| 160 kB 45.6 MB/s
# ...
#      |████████████████████████████████| 294 kB 39.5 MB/s
# ...
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=44871dd6528eb8ccd8a94b7142ff2369bb3755cabe6ccc8c7a80d89da197ea22
# ...

# %%
# !python test.py 7000
# Out:
# 0it [00:00, ?it/s]13983 업무상과실치상죄에 있어서 업무상배임죄에 있어서 ‘업무상 재해'의 의미 및 업무상 재해’에 해당하는지 여부의 판단 기준
# 1it [00:01,  1.35s/it]822 및 주거환경정비법에 의한 주택재개발조합이 주택재개발사업조합의 정관에 정한 정관에 의하여 정관조합이 정정한 정지조합이 되기 위한 요건
# 2it [00:04,  2.21s/it]13752 지입차주가 지입회사가 지입차주들이 지입회사 명의로 지입회사의 지입회사에 대하여 지입회사에게 지입회사를 대여한 경우, 지입주들 사이의 지입주주가 지입주들에게 지입차주의 명의를 신고하지 아니하였다고 단정할 수 있는지 여부 / 지입주에게 지입차량을 대여하였다고 볼 수 없다고 한 원심판결에 법리오해의 위법이 있다고 한 사례[2] 지입회사와 지입회사는 지입주들의 지입회사하여 지입주 명의주 명의신탁회사에 해당하지 아니한다고 한 사례[3] 지입주주의 지입회사 소유자의 지입회사로부터 지입주에 해당하지 않는다고 한 사례
# 3it [00:14,  6.03s/it]9656 甲 주식회사 주식회사가 주식회사에 대한 퇴직금 지급을 하였는데, 甲 회사가 甲 회사와 노동조합의 단체협약을 체결하였는데 甲 회사에 대한 퇴직금을 지급하기로 하였으나 甲 회사의 퇴직금을 지급하지 아니한 사안에서, 노동조합이 노동조합법상 퇴직금을 지급하였는데, 근로기준법상 단체협약에서 정한 퇴직금을 지급할 수 없다고 한 원심판결을 수긍한 사례 및 甲 회사 회사의 퇴직금 지급의 효력에 관한 법리오해의 위의 원칙에 관한 법리를 오해의 위법상의 위법이 위법이 유추해의 원칙에 비추어 무효라고 한 사례
# 4it [00:25,  7.94s/it]13497 자산운용회사가 자산운용회사의 투자비밀보호에관한법률 위반으로 인한 손해배상책임을 인정한 사례
# ...
